# %%
# !pip install ddgs groq crawl4ai PyPDF2 chromadb sentence-transformers requests beautifulsoup4 python-magic
import json

# %%
from ddgs import DDGS
from groq import Groq

client = Groq(api_key="")

def groq_llm(prompt):
    try:
        chat_completion = client.chat.completions.create(
            messages=[{"role": "user", "content": prompt}],
            model="llama-3.1-8b-instant",
            temperature=0.7,
            max_tokens=1024,
        )
        return chat_completion.choices[0].message.content
    except Exception as e:
        return f"Error: {str(e)}"

# %%
from datetime import datetime, timedelta
import json
from ddgs import DDGS
from groq import Groq



def search_urls(query: str, max_results: int = 20):
    try:
        ddgs = DDGS()
        results = []
        search_results = list(ddgs.text(query, max_results=max_results))

        for result in search_results:
            results.append({
                'title': result.get('title', ''),
                'url': result.get('href', ''),
                'snippet': result.get('body', '')
            })
        return results
    except Exception as e:
        print(f"Search error for '{query}': {e}")
        return []

# %%
def validate_source_relevance(source, original_query):
    """Validate if a source is relevant to the original query"""
    validation_prompt = f"""
    Analyze if this source is relevant to the query: "{original_query}"

    Source Title: {source['title']}
    Source Snippet: {source['snippet']}
    Source URL: {source['url']}

    Answer ONLY with "RELEVANT" or "IRRELEVANT" based on whether this source contains useful information about the query topic.
    Consider it RELEVANT if it contains government data, reports, policies, or official information related to the query.
    Consider it IRRELEVANT if it's completely unrelated, spam, or doesn't contain substantive information.
    """

    try:
        response = groq_llm(validation_prompt)
        response = response.strip().upper()
        return "RELEVANT" in response
    except Exception as e:
        print(f"Validation error: {e}")
        return True

# %%
def get_indian_gov_sources(user_query):
    print("🇮🇳 Analyzing query for Indian government sources...")

    analysis_prompt = f"""
    Analyze this Indian government query and break it into 10 core search topics:
    User Query: {user_query}

    Return only the topics as a numbered list, one per line.
    Focus on government-related aspects, policies, schemes, data, and reports.
    """
    analysis_result = groq_llm(analysis_prompt)
    print(f"Core search topics:\n{analysis_result}")

    search_topics = []
    for line in analysis_result.split('\n'):
        line = line.strip()
        if line and any(c.isalnum() for c in line):
            clean_string = line.lstrip('1234567890. -•')
            if clean_string and len(clean_string) > 5:
                search_topics.append(clean_string)

    print(f"Extracted {len(search_topics)} search topics")

    search_prompts = []
    for topic in search_topics[:3]:
        prompts = [
            f"{topic}",
            f"{topic} PDF",
            f"{topic} document",
            f"{topic} filetype:pdf",
            f"{topic} report",
            f"{topic} data",
            f"{topic} statistics",
            f"{topic} policy",
            f"{topic} scheme",
            f"{topic} guidelines",
            f"{topic} official document",
            f"{topic} government data",
            f"{topic} annual report",
            f"{topic} whitepaper",
            f"{topic} research paper",
            f"{topic} analysis report",
            f"{topic} dataset"
        ]
        search_prompts.extend(prompts)

    all_urls = []
    print(f"\nExecuting {len(search_prompts)} search queries...")

    for i, search_prompt in enumerate(search_prompts, 1):
        print(f"   {i}. Searching: '{search_prompt}'")
        urls = search_urls(search_prompt, 2)
        print(f"      Found {len(urls)} URLs")
        all_urls.extend(urls)

    unique_urls = []
    seen_urls = set()
    for url in all_urls:
        if url['url'] not in seen_urls:
            unique_urls.append(url)
            seen_urls.add(url['url'])

    print(f"\nFound {len(unique_urls)} unique URLs before validation")

    print(f"\nValidating source relevance...")
    relevant_urls = []

    for i, source in enumerate(unique_urls, 1):
        print(f"   {i}. Validating: {source['title'][:50]}...")

        if validate_source_relevance(source, user_query):
            relevant_urls.append(source)
            print(f"      RELEVANT - Keeping source")
        else:
            print(f"      IRRELEVANT - Discarding source")

    print(f"\nValidation Results:")
    print(f"   Total sources found: {len(unique_urls)}")
    print(f"   Relevant sources: {len(relevant_urls)}")
    print(f"   Irrelevant sources discarded: {len(unique_urls) - len(relevant_urls)}")

    filename = "indian_gov_sources.json"
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(relevant_urls, f, ensure_ascii=False, indent=4)

    print(f"\nSaved {len(relevant_urls)} relevant URLs to '{filename}'")

    return relevant_urls

# %%
if __name__ == "__main__":
    user_query = "Sewage Drainage Problems in Mumbai"
    results = get_indian_gov_sources(user_query)

    print(f"\nFinal Results:")
    for i, result in enumerate(results, 1):
        print(f"{i}. {result['title']}")
        print(f"   URL: {result['url']}")
        print(f"   Snippet: {result['snippet'][:100]}...")
        print()
# Out:
# 🇮🇳 Analyzing query for Indian government sources...
# Core search topics:
# 1. Mumbai Sewage Drainage System
# 2. Government Schemes for Sewage Management in Mumbai
# 3. Mumbai Municipal Corporation's Sewage Drainage Policy
# 4. Sewage Drainage Data for Mumbai
# 5. Government Reports on Mumbai's Sewage Drainage Issues
# 6. Mumbai's Sewage Drainage Infrastructure Development
# 7. Water Conservation and Sewage Management in Mumbai
# 8. Mumbai's Sewage Drainage Budget Allocation
# 9. Government Initiatives to Prevent Sewage Pollution in Mumbai
# 10. Mumbai's Sewage Drainage Regulatory Framework
# Extracted 10 search topics
#
# Executing 51 search queries...
#    1. Searching: 'Mumbai Sewage Drainage System'
#       Found 2 URLs
#    2. Searching: 'Mumbai Sewage Drainage System PDF'
#       Found 2 URLs
#    3. Searching: 'Mumbai Sewage Drainage System document'
#       Found 2 URLs
#    4. Searching: 'Mumbai Sewage Drainage System filetype:pdf'
#       Found 2 URLs
#    5. Searching: 'Mumbai Sewage Drainage System report'
#       Found 2 URLs
#    6. Searching: 'Mumbai Sewage Drainage System data'
#       Found 2 URLs
#    7. Searching: 'Mumbai Sewage Drainage System statistics'
#       Found 2 URLs
#    8. Searching: 'Mumbai Sewage Drainage System policy'
#       Found 2 URLs
#    9. Searching: 'Mumbai Sewage Drainage System scheme'
#       Found 2 URLs
#    10. Searching: 'Mumbai Sewage Drainage System guidelines'
#       Found 2 URLs
#    11. Searching: 'Mumbai Sewage Drainage System official document'
#       Found 2 URLs
#    12. Searching: 'Mumbai Sewage Drainage System government data'
#       Found 2 URLs
#    13. Searching: 'Mumbai Sewage Drainage System annual report'
#       Found 2 URLs
#    14. Searching: 'Mumbai Sewage Drainage System whitepaper'
#       Found 2 URLs
#    15. Searching: 'Mumbai Sewage Drainage System research paper'
#       Found 2 URLs
#    16. Searching: 'Mumbai Sewage Drainage System analysis report'
#       Found 2 URLs
#    17. Searching: 'Mumbai Sewage Drainage System dataset'
#       Found 2 URLs
#    18. Searching: 'Government Schemes for Sewage Management in Mumbai'
#       Found 2 URLs
#    19. Searching: 'Government Schemes for Sewage Management in Mumbai PDF'
#       Found 2 URLs
#    20. Searching: 'Government Schemes for Sewage Management in Mumbai document'
#       Found 2 URLs
#    21. Searching: 'Government Schemes for Sewage Management in Mumbai filetype:pdf'
#       Found 2 URLs
#    22. Searching: 'Government Schemes for Sewage Management in Mumbai report'
#       Found 2 URLs
#    23. Searching: 'Government Schemes for Sewage Management in Mumbai data'
#       Found 2 URLs
#    24. Searching: 'Government Schemes for Sewage Management in Mumbai statistics'
#       Found 2 URLs
#    25. Searching: 'Government Schemes for Sewage Management in Mumbai policy'
#       Found 2 URLs
#    26. Searching: 'Government Schemes for Sewage Management in Mumbai scheme'
#       Found 2 URLs
#    27. Searching: 'Government Schemes for Sewage Management in Mumbai guidelines'
#       Found 2 URLs
#    28. Searching: 'Government Schemes for Sewage Management in Mumbai official document'
#       Found 2 URLs
#    29. Searching: 'Government Schemes for Sewage Management in Mumbai government data'
#       Found 2 URLs
#    30. Searching: 'Government Schemes for Sewage Management in Mumbai annual report'
#       Found 2 URLs
#    31. Searching: 'Government Schemes for Sewage Management in Mumbai whitepaper'
#       Found 2 URLs
#    32. Searching: 'Government Schemes for Sewage Management in Mumbai research paper'
#       Found 2 URLs
#    33. Searching: 'Government Schemes for Sewage Management in Mumbai analysis report'
#       Found 2 URLs
#    34. Searching: 'Government Schemes for Sewage Management in Mumbai dataset'
#       Found 2 URLs
#    35. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy'
#       Found 2 URLs
#    36. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy PDF'
#       Found 2 URLs
#    37. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy document'
#       Found 2 URLs
#    38. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy filetype:pdf'
#       Found 2 URLs
#    39. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy report'
#       Found 2 URLs
#    40. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy data'
#       Found 2 URLs
#    41. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy statistics'
#       Found 2 URLs
#    42. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy policy'
#       Found 2 URLs
#    43. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy scheme'
#       Found 2 URLs
#    44. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy guidelines'
#       Found 2 URLs
#    45. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy official document'
#       Found 2 URLs
#    46. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy government data'
#       Found 2 URLs
#    47. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy annual report'
#       Found 2 URLs
#    48. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy whitepaper'
#       Found 2 URLs
#    49. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy research paper'
#       Found 2 URLs
#    50. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy analysis report'
#       Found 2 URLs
#    51. Searching: 'Mumbai Municipal Corporation's Sewage Drainage Policy dataset'
#       Found 2 URLs
#
# Found 37 unique URLs before validation
#
# Validating source relevance...
#    1. Validating: Brihanmumbai Storm Water Disposal System - Wikiped...
#       RELEVANT - Keeping source
#    2. Validating: Explainer: Where does sewage in Mumbai go? - Citiz...
#       RELEVANT - Keeping source
#    3. Validating: Sustainable Underground Water Drainage System for ...
#       RELEVANT - Keeping source
#    4. Validating: MUMBAI SEWER PROJECTS STAGE I & II - Terratec...
#       RELEVANT - Keeping source
#    5. Validating: City sanitation plan for Mumbai...
#       RELEVANT - Keeping source
#    6. Validating: Sewer System Design in DWG (2.33 MB) | CAD library...
#       RELEVANT - Keeping source
#    7. Validating: 25% of Mumbai sewage flows untreated into sea - Ti...
#       RELEVANT - Keeping source
#    8. Validating: Mumbai Tourism | Mumbai Tourist Places | Mumbai Tr...
#       RELEVANT - Keeping source
#    9. Validating: US-bound Air India flight returns to Mumbai, pilot...
#       RELEVANT - Keeping source
#    10. Validating: Sewers and sewage treatment in Mumbai: Temporality...
#       RELEVANT - Keeping source
#    11. Validating: Status of Civic Issues in Mumbai 1 - PRAJA...
#       RELEVANT - Keeping source
#    12. Validating: Hardlook: Mumbai ’s woefully inadequate sewage ......
#       RELEVANT - Keeping source
#    13. Validating: Water Security and Urban Rivers: Lessons from Mumb...
#       RELEVANT - Keeping source
#    14. Validating: (PDF) Evaluation of the costs and benefits of mumb...
#       RELEVANT - Keeping source
#    15. Validating: Cabinet clears Mumbai slum cluster redevelopment p...
#       RELEVANT - Keeping source
#    16. Validating: Schemes | Mumbai Suburban District, Government of ...
#       RELEVANT - Keeping source
#    17. Validating: Making government services easier to find | USAGov...
#       RELEVANT - Keeping source
#    18. Validating: The U.S. and its government - USAGov...
#       RELEVANT - Keeping source
#    19. Validating: City Waste Management Profile: Mumbai, India...
#       RELEVANT - Keeping source
#    20. Validating: A Case Study Report on Waste water management & Se...
#       RELEVANT - Keeping source
#    21. Validating: CAG Report : ‘Financial irregularities’ found in.....
#       RELEVANT - Keeping source
#    22. Validating: Understanding Mumbai 's Sewage Treatment... - Dive...
#       RELEVANT - Keeping source
#    23. Validating: Solution Exchange discussion: Best Practices in Ef...
#       RELEVANT - Keeping source
#    24. Validating: Sewage Treatment Plants in Mumbai : A Perspective ...
#       RELEVANT - Keeping source
#    25. Validating: India’s Sustainability Push: 30 Government Schemes...
#       RELEVANT - Keeping source
#    26. Validating: Water and Sanitation | Sector | Open Government Da...
#       RELEVANT - Keeping source
#    27. Validating: Mumbai RfP _Waste Composition.docx - C40 Cities...
#       RELEVANT - Keeping source
#    28. Validating: Treated sewage water for non-potable use: BMC’s am...
#       RELEVANT - Keeping source
#    29. Validating: cdp_ilfs-jan-31-06 - Mumbai...
#       RELEVANT - Keeping source
#    30. Validating: Mumbai flood: Development proposals are blocking n...
#       RELEVANT - Keeping source
#    31. Validating: MUNICIPAL CORPORATION OF GREATER MUMBAI...
#       RELEVANT - Keeping source
#    32. Validating: Mumbai Civic Diary 2025 | PDF | Sanitary Sewer | S...
#       RELEVANT - Keeping source
#    33. Validating: Section 239 in The Mumbai Municipal Corporation Ac...
#       RELEVANT - Keeping source
#    34. Validating: All the reasons why Mumbai will be under water aga...
#       RELEVANT - Keeping source
#    35. Validating: Mumbai - Wikipedia...
#       RELEVANT - Keeping source
#    36. Validating: Datasets - OpenCity - Urban Data Portal...
#       RELEVANT - Keeping source
#    37. Validating: Sewage management challenges in mega cities in Ind...
#       RELEVANT - Keeping source
#
# Validation Results:
#    Total sources found: 37
#    Relevant sources: 37
#    Irrelevant sources discarded: 0
#
# Saved 37 relevant URLs to 'indian_gov_sources.json'
#
# Final Results:
# 1. Brihanmumbai Storm Water Disposal System - Wikipedia
#    URL: https://en.wikipedia.org/wiki/Brihanmumbai_Storm_Water_Disposal_System
#    Snippet: The Brihanmumbai Stormwater Disposal System is a project planned to overhaul Mumbai 's water drainag...
#
# 2. Explainer: Where does sewage in Mumbai go? - Citizen Matters
#    URL: https://citizenmatters.in/explainer-sewage-in-mumbai-treatment-disposal/
#    Snippet: Mar 15, 2022 · Mumbai ’ s sewage network covers only 84% of the city and 68% of the population, as o...
#
# 3. Sustainable Underground Water Drainage System for Mumbai City
#    URL: https://www.ijert.org/research/sustainable-underground-water-drainage-system-for-mumbai-city-IJERTV8IS060285.pdf
#    Snippet: Project work on sustainable underground drainage system is undertaken. There is need to control floo...
#
# 4. MUMBAI SEWER PROJECTS STAGE I & II - Terratec
#    URL: https://terratec.co/wp-content/uploads/2024/05/Terratec-Project-Reference-Mumbai-Sewer-Projects-PST-I-II.pd
#    URL: https://www.mcgm.gov.in/irj/go/km/docs/documents/MCGM+Department+List/City+Engineer/Deputy+City+Engineer+(Planning+and+Design)/City+Development+Plan/Urban+Basic+Services.pdf
#    Snippet: The Sewerage Master Plan prepared in 1979 by Metcalf & Eddy Inc. formed a basis for the conveyance a...
#
# 30. Mumbai flood: Development proposals are blocking natural drainage ...
#    URL: https://scroll.in/article/886210/mumbai-floods-the-development-crazy-city-must-stop-blocking-natural-drainage-channels-with-concrete
#    Snippet: A failed drainage project. The Brihanmumbai Municipal Corporation is India’ s richest civic body, wi...
#
# 31. MUNICIPAL CORPORATION OF GREATER MUMBAI
#    URL: https://www.mcgm.gov.in/irj/go/km/docs/documents/Tenders/ETH/VolumeII_7000009684.pdf
#    Snippet: The sewage collection system, the wastewater treatment, and the effluent disposal systems in Mumbai ...
#
# 32. Mumbai Civic Diary 2025 | PDF | Sanitary Sewer | Sewage Treatment
#    URL: https://www.scribd.com/document/888428917/Mumbai-Civic-Diary-2025
#    Snippet: The document outlines the structure and functions of various municipal authorities in Mumbai as per ...
#
# 33. Section 239 in The Mumbai Municipal Corporation Act, 1888
#    URL: https://indiankanoon.org/doc/60254496/
#    Snippet: - Whenever it is provided in this Chapter that steps shall or may be taken for the effectual drainag...
#
# 34. All the reasons why Mumbai will be under water again next year, and...
#    URL: https://qz.com/india/1071407/all-the-reasons-why-mumbai-will-be-under-water-again-next-year-and-the-year-after-that
#    Snippet: Another cause of chronic flooding is the city’ s inefficient water drainage system. Combined with un...
#
# 35. Mumbai - Wikipedia
#    URL: https://en.wikipedia.org/wiki/Mumbai
#    Snippet: Although the municipal corporation is the legislative body that lays down policies for the governanc...
#
# 36. Datasets - OpenCity - Urban Data Portal
#    URL: https://data.opencity.in/dataset?organization=brihanmumbai-municipal-corporation-bmc-mcgm
#    Snippet: Wards map of Mumbai with locations of ward offices. The maps are based on the ones on the MCGM websi...
#
# 37. Sewage management challenges in mega cities in India: a case ...
#    URL: https://www.deswater.com/DWT_articles/vol_116_papers/116_2018_329.pdf
#    Snippet: The discharge of untreated sewage in open drains , unplanned development of the city and encroachmen...

# %%
import os
import json
import asyncio
import requests
from datetime import datetime, timedelta
from ddgs import DDGS
from groq import Groq
import PyPDF2
import chromadb
from sentence_transformers import SentenceTransformer
from crawl4ai import AsyncWebCrawler
from crawl4ai.async_configs import BrowserConfig, CrawlerRunConfig
import urllib.parse



# async def crawl_urls_from_json(json_file_path, output_file="crawled_results.json"):
#     with open(json_file_path, 'r', encoding='utf-8') as f:
#         data = json.load(f)

#     browser_config = BrowserConfig()

#     run_config = CrawlerRunConfig(
#         word_count_threshold=10,
#         remove_overlay_elements=True,
#         exclude_external_links=False
#     )

#     results = []

#     async with AsyncWebCrawler(config=browser_config) as crawler:
#         for item in data:
#             url = item["url"]
#             print(f"Crawling: {url}")

#             try:
#                 result = await crawler.arun(url=url, config=run_config)

#                 crawled_data = {
#                     "title": item["title"],
#                     "url": url,
#                     "snippet": item["snippet"],
#                     "success": result.success,
#                     "status_code": result.status_code,
#                     "markdown_content": result.markdown if result.success else None,
#                     "error_message": result.error_message if not result.success else None
#                 }
#                 results.append(crawled_data)

#                 if result.success:
#                     print(f"✓ Successfully crawled: {url}")
#                 else:
#                     print(f"✗ Failed to crawl: {url} - {result.error_message}")

#             except Exception as e:
#                 print(f"✗ Error crawling {url}: {str(e)}")
#                 results.append({
#                     "title": item["title"],
#                     "url": url,
#                     "snippet": item["snippet"],
#                     "success": False,
#                     "status_code": None,
#                     "markdown_content": None,
#                     "error_message": str(e)
#                 })

#     with open(output_file, 'w', encoding='utf-8') as f:
#         json.dump(results, f, indent=2, ensure_ascii=False)

#     print(f"\nCrawling completed! Results saved to: {output_file}")

#     successful_crawls = sum(1 for r in results if r["success"])
#     print(f"Successfully crawled: {successful_crawls}/{len(data)} URLs")

# %%
async def crawl_urls_from_json(json_file_path, output_file="crawled_results.json"):
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    browser_config = BrowserConfig()
    run_config = CrawlerRunConfig(
        word_count_threshold=10,
        remove_overlay_elements=True,
        exclude_external_links=False
    )

    results = []

    async with AsyncWebCrawler(config=browser_config) as crawler:
        for item in data:
            url = item["url"]
            print(f"Crawling: {url}")

            try:
                result = await crawler.arun(url=url, config=run_config)

                crawled_data = {
                    "title": item["title"],
                    "url": url,
                    "snippet": item["snippet"],
                    "success": result.success,
                    "markdown_content": result.markdown if result.success else None,
                    "error_message": result.error_message if not result.success else None
                }
                results.append(crawled_data)

                if result.success:
                    print(f"✓ Successfully crawled: {url}")
                else:
                    print(f"✗ Failed to crawl: {url}")

            except Exception as e:
                print(f"✗ Error crawling {url}: {str(e)}")
                results.append({
                    "title": item["title"],
                    "url": url,
                    "snippet": item["snippet"],
                    "success": False,
                    "markdown_content": None,
                    "error_message": str(e)
                })

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"\nCrawling completed! Results saved to: {output_file}")
    return results

def run_crawler():
    """Run the crawler (wrapper for async function)"""
    return crawl_urls_from_json("indian_gov_sources.json")

# %%
client = Groq(api_key="")

os.makedirs("files", exist_ok=True)
os.makedirs("pdfs", exist_ok=True)
os.makedirs("docs", exist_ok=True)

# %%
def download_file(url, folder="files"):
    """Download files from URLs"""
    try:
        parsed_url = urllib.parse.urlparse(url)
        filename = os.path.basename(parsed_url.path)

        if not filename:
            filename = f"downloaded_file_{hash(url)}"

        filepath = os.path.join(folder, filename)

        # Download the file
        response = requests.get(url, timeout=30)
        response.raise_for_status()

        with open(filepath, 'wb') as f:
            f.write(response.content)

        print(f"Downloaded: {filename}")
        return filepath

    except Exception as e:
        print(f"Failed to download {url}: {e}")
        return None

# %%
def download_files_from_sources(json_file):
    with open(json_file, 'r', encoding='utf-8') as f:
        sources = json.load(f)

    downloaded_files = []

    for source in sources:
        url = source['url']

        if any(url.lower().endswith(ext) for ext in ['.pdf', '.doc', '.docx', '.xls', '.xlsx', '.ppt', '.pptx']):
            filepath = download_file(url)
            if filepath:
                downloaded_files.append({
                    'source_title': source['title'],
                    'url': url,
                    'filepath': filepath,
                    'file_type': os.path.splitext(filepath)[1].lower()
                })

    with open("downloaded_files.json", "w", encoding="utf-8") as f:
        json.dump(downloaded_files, f, indent=2, ensure_ascii=False)

    print(f"\nDownloaded {len(downloaded_files)} files")
    return downloaded_files

# %%
# !pip install crawl4ai ddgs
# !playwright install
# !pip install groq

# %%
async def crawl_urls_from_json(json_file_path, output_file="crawled_results.json"):
    with open(json_file_path, 'r', encoding='utf-8') as f:
        data = json.load(f)

    browser_config = BrowserConfig()
    run_config = CrawlerRunConfig(
        word_count_threshold=10,
        remove_overlay_elements=True,
        exclude_external_links=False
    )

    results = []

    async with AsyncWebCrawler(config=browser_config) as crawler:
        for item in data:
            url = item["url"]
            print(f"Crawling: {url}")

            try:
                result = await crawler.arun(url=url, config=run_config)

                crawled_data = {
                    "title": item["title"],
                    "url": url,
                    "snippet": item["snippet"],
                    "success": result.success,
                    "markdown_content": result.markdown if result.success else None,
                    "error_message": result.error_message if not result.success else None
                }
                results.append(crawled_data)

                if result.success:
                    print(f"✓ Successfully crawled: {url}")
                else:
                    print(f"✗ Failed to crawl: {url}")

            except Exception as e:
                print(f"✗ Error crawling {url}: {str(e)}")
                results.append({
                    "title": item["title"],
                    "url": url,
                    "snippet": item["snippet"],
                    "success": False,
                    "markdown_content": None,
                    "error_message": str(e)
                })

    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)

    print(f"\nCrawling completed! Results saved to: {output_file}")
    return results

# %%
def run_crawler():
    """Run the crawler (wrapper for async function)"""
    return asyncio.run(crawl_urls_from_json("indian_gov_sources.json"))

# %%
def extract_text_from_pdf(pdf_path):
    """Extract text from PDF file"""
    try:
        text = ""
        with open(pdf_path, 'rb') as file:
            pdf_reader = PyPDF2.PdfReader(file)
            for page_num in range(len(pdf_reader.pages)):
                page = pdf_reader.pages[page_num]
                text += page.extract_text() + "\n"
        return text
    except Exception as e:
        print(f"Error extracting text from {pdf_path}: {e}")
        return ""

# %%
def chunk_text(text, chunk_size=500, overlap=50):
    """Split text into overlapping chunks"""
    words = text.split()
    chunks = []

    for i in range(0, len(words), chunk_size - overlap):
        chunk = ' '.join(words[i:i + chunk_size])
        chunks.append(chunk)

        if i + chunk_size >= len(words):
            break

    return chunks

# %%
def process_pdf_folder(pdf_folder="files"):
    """Process all PDFs in a folder and extract text"""
    pdf_data = []

    for filename in os.listdir(pdf_folder):
        if filename.lower().endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder, filename)
            print(f"Processing PDF: {filename}")

            text = extract_text_from_pdf(pdf_path)
            chunks = chunk_text(text)

            for i, chunk in enumerate(chunks):
                pdf_data.append({
                    "filename": filename,
                    "chunk_id": i,
                    "text": chunk,
                    "total_chunks": len(chunks)
                })

    with open("extracted_pdf_text.json", "w", encoding="utf-8") as f:
        json.dump(pdf_data, f, indent=2, ensure_ascii=False)

    print(f"Processed {len(pdf_data)} chunks from PDFs")
    return pdf_data

# %%
def setup_vector_db():
    """Initialize ChromaDB and sentence transformer"""
    model = SentenceTransformer('all-MiniLM-L6-v2')
    chroma_client = chromadb.Client()
    collection = chroma_client.create_collection(name="documents")
    return model, collection

# %%
def add_to_vector_db(documents, metadatas, collection, model):
    """Add documents to vector database"""
    if not documents:
        print("No documents to add to vector DB")
        return

    embeddings = model.encode(documents).tolist()

    ids = [f"doc_{i}" for i in range(len(documents))]

    collection.add(
        embeddings=embeddings,
        documents=documents,
        metadatas=metadatas,
        ids=ids
    )

    print(f"Added {len(documents)} documents to vector database")

# %%
def process_all_data_for_vector_db():
    """Process all crawled and PDF data for vector DB"""
    model, collection = setup_vector_db()

    all_documents = []
    all_metadatas = []

    if os.path.exists("crawled_results.json"):
        with open("crawled_results.json", 'r', encoding='utf-8') as f:
            crawled_data = json.load(f)

        for item in crawled_data:
            if item.get('success') and item.get('markdown_content'):
                all_documents.append(item['markdown_content'])
                all_metadatas.append({
                    "source": "web_crawl",
                    "title": item.get('title', ''),
                    "url": item.get('url', '')
                })

    if os.path.exists("extracted_pdf_text.json"):
        with open("extracted_pdf_text.json", 'r', encoding='utf-8') as f:
            pdf_data = json.load(f)

        for item in pdf_data:
            all_documents.append(item['text'])
            all_metadatas.append({
                "source": "pdf",
                "filename": item['filename'],
                "chunk_id": item['chunk_id']
            })

    add_to_vector_db(all_documents, all_metadatas, collection, model)
    print(f"Total documents in vector DB: {len(all_documents)}")

    return collection

# %%
async def main_workflow(user_query):
    # print("Starting complete workflow...")
    # sources = get_indian_gov_sources(user_query)

    print("Downloading files")
    downloaded_files = download_files_from_sources("indian_gov_sources.json")


    print("Crawling web pages")
    crawled_results = await run_crawler()

    print("Processing PDFs")
    pdf_data = process_pdf_folder()

    print("Creating vector database")
    collection = process_all_data_for_vector_db()

    print("\nWorkflow completed successfully!")
    return collection

if __name__ == "__main__":
    test_query = "Digital India initiative"
    await main_workflow(test_query)
# Out:
# Downloading files
# Downloaded: sustainable-underground-water-drainage-system-for-mumbai-city-IJERTV8IS060285.pdf
# Downloaded: Terratec-Project-Reference-Mumbai-Sewer-Projects-PST-I-II.pdf
# Failed to download https://www.pas.org.in/Portal/document/ResourcesFiles/WorkshopPDFs/Citywide+Sanitation+Workshop/7_CSP+Mumbai+(A+Kantak).pdf: 404 Client Error: /Portal/document/ResourcesFiles/WorkshopPDFs/Citywide+Sanitation+Workshop/7_CSP+Mumbai+(A+Kantak).pdf for url: https://www.pas.org.in/Portal/document/ResourcesFiles/WorkshopPDFs/Citywide+Sanitation+Workshop/7_CSP+Mumbai+(A+Kantak).pdf
# Failed to download https://praja.org/praja_docs/praja_downloads/Status+of+Civic+Issues+in+Mumbai+2024.pdf: 404 Client Error: Not Found for url: https://praja.org/praja_docs/praja_downloads/Status+of+Civic+Issues+in+Mumbai+2024.pdf
# Downloaded: City-Waste-Management-Profile-Mumbai-India.pdf
# Downloaded: JETIR2104153.pdf
# Downloaded: Mumbai-RfP-_Waste-Composition-2.pdf
# Failed to download https://www.mcgm.gov.in/irj/go/km/docs/documents/MCGM+Department+List/City+Engineer/Deputy+City+Engineer+(Planning+and+Design)/City+Development+Plan/Urban+Basic+Services.pdf: 404 Client Error: Not Found for url: https://www.mcgm.gov.in/irj/go/km/docs/documents/MCGM+Department+List/City+Engineer/Deputy+City+Engineer+(Planning+and+Design)/City+Development+Plan/Urban+Basic+Services.pdf
# Downloaded: VolumeII_7000009684.pdf
# Downloaded: 116_2018_329.pdf
#
# Downloaded 7 files
# Crawling web pages
# [INIT].... → Crawl4AI 0.7.6
# Crawling: https://en.wikipedia.org/wiki/Brihanmumbai_Storm_Water_Disposal_System
# [FETCH]... ↓ https://en.wikipedia.org/wiki/Brihanmumbai_Storm_Water_Disposal_System                               |
# ✓ | ⏱: 3.15s
# [SCRAPE].. ◆ https://en.wikipedia.org/wiki/Brihanmumbai_Storm_Water_Disposal_System                               |
# ✓ | ⏱: 0.14s
# [COMPLETE] ● https://en.wikipedia.org/wiki/Brihanmumbai_Storm_Water_Disposal_System                               |
# ✓ | ⏱: 3.30s
# ✓ Successfully crawled: https://en.wikipedia.org/wiki/Brihanmumbai_Storm_Water_Disposal_System
# Crawling: https://citizenmatters.in/explainer-sewage-in-mumbai-treatment-disposal/
# [FETCH]... ↓ https://citizenmatters.in/explainer-sewage-in-mumbai-treatment-disposal/                             |
# ✓ | ⏱: 10.65s
# [SCRAPE].. ◆ https://citizenmatters.in/explainer-sewage-in-mumbai-treatment-disposal/                             |
# ✓ | ⏱: 0.12s
# [COMPLETE] ● https